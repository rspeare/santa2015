# %%
import numpy as np
import pandas as pd
import imp
import mTSP
imp.reload(mTSP)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %ls ../data/*trips.csv
# Out:
# ../data/1001trips.csv  ../data/1500trips.csv  ../data/2002trips.csv
# ../data/1444trips.csv  ../data/1600trips.csv  ../data/2003trips.csv
# ../data/1450trips.csv  ../data/2000trips.csv
# ../data/1477trips.csv  ../data/2001trips.csv

# %%
imp.reload(mTSP)
m=mTSP.mission(20)
m.read_submission('../data/1001trips.csv')
loads=m.check_loads()
print('number of trips',len(m.trips))
print('score',m.loss())
plt.figure(figsize=(8,6))
ax1=plt.subplot(211)
ax1.hist(loads,30)

ax2=plt.subplot(212)
ax2.hist([len(t) for t in m.trips],30)
#plt.hist([len(t) for t in m.trips])
plt.show()
# Out:
# number of trips 9176
# score 16296820815.7

# %%
imp.reload(mTSP)
m=mTSP.mission(20)
m.read_submission('../data/2003trips.csv')
loads=m.check_loads()
print('number of trips',len(m.trips))
print('score',m.loss())
plt.figure(figsize=(8,6))
ax1=plt.subplot(211)
ax1.hist(loads,30)

ax2=plt.subplot(212)
ax2.hist([len(t) for t in m.trips],30)
#plt.hist([len(t) for t in m.trips])
plt.show()
# Out:
# number of trips 16349
# score 16520427587.1

# %%
imp.reload(mTSP)
m=mTSP.mission(20)
m.read_submission('../data/2002trips.csv')
loads=m.check_loads()
print('number of trips',len(m.trips))
print('score',m.loss())
plt.figure(figsize=(8,6))
ax1=plt.subplot(211)
ax1.hist(loads,30)

ax2=plt.subplot(212)
ax2.hist([len(t) for t in m.trips],30)
#plt.hist([len(t) for t in m.trips])
plt.show()
# Out:
# number of trips 9763
# score 15280509641.1

# %%
imp.reload(mTSP)
m=mTSP.mission(20)
m.read_submission('../data/1500trips.csv')
loads=m.check_loads()
print('number of trips',len(m.trips))
print('score',m.loss())
plt.figure(figsize=(8,6))
ax1=plt.subplot(211)
ax1.hist(loads,30)

ax2=plt.subplot(212)
ax2.hist([len(t) for t in m.trips],30)
#plt.hist([len(t) for t in m.trips])
plt.show()
# Out:
# number of trips 10470
# score 14783997592.9

# %%
#m.anneal(1500,10**3,10**4,10**2,.99,100)

# %%
imp.reload(mTSP)
m=mTSP.mission(20)
m.read_submission('../data/2001trips.csv')
loads=m.check_loads()
print('number of trips',len(m.trips))
print('score',m.loss())
plt.figure(figsize=(8,6))
ax1=plt.subplot(211)
ax1.hist(loads,30)

ax2=plt.subplot(212)
ax2.hist([len(t) for t in m.trips],30)
#plt.hist([len(t) for t in m.trips])
plt.show()
# Out:
# number of trips 12850
# score 15496553542.9

# %%
m.check_tmap()
print(len(m.trips))
lads=m.check_loads()

# %%
m.anneal(2001,10**2.6,10**5,10**2,.99,10**3)

# %%
#m.anneal(1001,10**6,10**5,10**2,.95,10**3)
